# %%
import common

# %%
df = common.main_price_tbl()
# Out:
# /home/kimon/dev/bin/renai/dev-py/common.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
corrs= []

focus = "POWL"
for ticker in df['ticker'].drop_duplicates():
    focus_df = df[df['ticker'] == focus][['dated', 'adj_close']]

    temp = df[df['ticker'] == ticker][['dated', 'adj_close']]
    corr = temp.loc['adj_close', 'value']

    row = pd.DataFrame({'ticker': ticker, 'corr': corr}, index=[0])
    corrs.append(row)

corrs = pd.concat(corrs, ignore_index=True)
corrs = corrs.dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 corrs= []
#       3 focus = "POWL"
# ----> 4 for ticker in df['ticker'].drop_duplicates():
#       5     focus_df = df[df['ticker'] == focus][['dated', 'adj_close']]
#       7     temp = df[df['ticker'] == ticker][['dated', 'adj_close']]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import psycopg2
import pandas as pd

def main_price_tbl():
    conn = psycopg2.connect(
        host="localhost",
        database="renai",
        user="overseer",
        password="password",
    )

    query="""
        SELECT * FROM stock.price_view
    """

    df = pd.read_sql_query(query, conn)
    df['date'] = df['dated']

    conn.close()

    return df

# %%
main_price_tbl()
# Out:
# /tmp/ipykernel_14536/1674119286.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#            stock_id ticker                                      title  \
# 0        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# 1        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# 2        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# 3        0000320193   AAPL                                 Apple Inc.
# 4        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# ...             ...    ...                                        ...
# 3300631  0000867773   SPWR                              SUNPOWER CORP
# 3300632  0000867773   SPWR                              SUNPOWER CORP
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://overseer:password@localhost:5432/renai')
df = pd.read_sql_query('''
    SELECT * FROM stock.price_view
''', con=engine)

# %%
df.dropna()
# Out:
#            stock_id ticker                                      title  \
# 0        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# 1        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# 2        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# 3        0000320193   AAPL                                 Apple Inc.
# 4        0001046179    TSM  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
# ...             ...    ...                                        ...
# 3300628  0000867773   SPWR                              SUNPOWER CORP
# 3300629  0000867773   SPWR                              SUNPOWER CORP
# 3300630  0000867773   SPWR                              SUNPOWER CORP
# 3300631  0000867773   SPWR                              SUNPOWER CORP
# 3300632  0000867773   SPWR                              SUNPOWER CORP
#
#               dated     opening        high         low     closing  \
# ...
